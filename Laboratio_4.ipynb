# %% [markdown]
# ## Laboratorio #4: Diego Alonso Ulate Jara

# %%
import folium
from folium.plugins import minimap

costaRica = folium.Map(location = (10.342642666140456, -83.95592757811875))
folium.Marker(location=[9.99894050837749, -84.11119520273513],popup="<p>Campus Omar Dengo</p>", icon= folium.Icon(color="orange", icon= "ok-sign")).add_to(costaRica)
folium.Marker(location=[9.971065325453926, -84.12844501927123],popup="<p>Campus Benjamin Nuñez</p>", icon= folium.Icon(color="orange", icon= "ok-sign")).add_to(costaRica)
folium.Marker(location=[10.019997964009459, -84.19605975872133],popup="<p>Campus Interuniversitario</p>", icon= folium.Icon(color="orange", icon= "ok-sign")).add_to(costaRica)
folium.Marker(location=[10.319428764236665, -83.9227897200776],popup="<p>Campus Sarapiquí</p>", icon= folium.Icon(color="orange", icon= "ok-sign")).add_to(costaRica)
folium.Marker(location=[8.573577888309977, -82.87240241743562],popup="<p>Campus Coto</p>", icon= folium.Icon(color="orange", icon= "ok-sign")).add_to(costaRica)
folium.Marker(location=[9.39937102741411, -83.69151426708058],popup="<p>Campus Pérez Zeledón</p>", icon= folium.Icon(color="orange", icon= "ok-sign")).add_to(costaRica)
folium.Marker(location=[10.617825984554647, -85.4500216067346],popup="<p>Campus Liberia</p>", icon= folium.Icon(color="orange", icon= "ok-sign")).add_to(costaRica)
folium.Marker(location=[10.134882861953827, -85.44788169470999],popup="<p>Campus Nicoya</p>", icon= folium.Icon(color="orange", icon= "ok-sign")).add_to(costaRica)

# %%
costaRica
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
# ...
